# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi = np.linspace(0,10,20)

# %%
numpyDizisi
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi**2

# %%
numpyDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigur,benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi,numpyDizisi2,color = "#b103fc",alpha = 0.3)# alpha tranparancy
benimEksen.plot(numpyDizisi2,numpyDizisi,color = "#fc0398")

# %%
(yeniFigur, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi,numpyDizisi + 2,color="blue",linewidth = 1.0)
yeniEksen.plot(numpyDizisi,numpyDizisi + 3,color="#b103fc",linewidth = 3.0)

yeniEksen.plot(numpyDizisi,numpyDizisi + 4,color="#fca503",linestyle = "-.")
yeniEksen.plot(numpyDizisi,numpyDizisi + 5,color="#fc2803",linestyle = ":")
yeniEksen.plot(numpyDizisi,numpyDizisi + 6,color="#2dfc03",linestyle = "--")

yeniEksen.plot(numpyDizisi,numpyDizisi + 7,color="#000000",linestyle = "--",marker ="o",markersize=4,markerfacecolor ="yellow")

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpyDizisi,numpyDizisi2)

# %% [markdown]
# ## histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([22, 57, 11,  1, 33, 47, 59, 12,  5, 95, 27, 64, 51,  4,  8, 53, 82,
#        90, 34, 10, 86, 70, 92, 37,  9, 60, 23, 98, 67, 95, 22, 79, 58,  8,
#        83, 62, 46, 73, 61, 80, 55, 80, 84, 39, 72, 49, 59, 42, 32, 42])

# %%
plt.hist(yeniDizi)
# Out:
# (array([7., 2., 4., 5., 5., 7., 5., 3., 7., 5.]),
#  array([ 1. , 10.7, 20.4, 30.1, 39.8, 49.5, 59.2, 68.9, 78.6, 88.3, 98. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1c149336010>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1c149357710>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1c149355450>],
#  'medians': [<matplotlib.lines.Line2D at 0x1c14935cd90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1c149343ad0>],
#  'means': []}
